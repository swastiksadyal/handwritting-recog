# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (7.0.0)

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28) (60000,)

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
batch_size = 128
num_classes = 10
epochs = 10


x_train = x_train.reshape(x_train.shape[0], 28,28, 1)
x_test = x_test.reshape(x_test.shape[0], 28,28, 1)
input_shape = (28, 28, 1)

#convert class ves to binaray class metrices hu lulu
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

#_______________________________

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

print('x_train shape: ', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape:  (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ### create the kiddo

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss = keras.losses.categorical_crossentropy,
              optimizer = keras.optimizers.Adadelta(),
              metrics = ['accuracy'])

# %% [markdown]
# # Train the kiddo!

# %%
hist = model.fit(x_train,y_train,batch_size = batch_size, epochs = epochs, verbose = 1, validation_data=(x_test, y_test))
print("the model is trained!!")
model.save('mnist.h5')
print("saved the model as mnist.h5")
# Out:
# Epoch 1/10
# 469/469 [==============================] - 151s 323ms/step - loss: 2.2848 - accuracy: 0.1538 - val_loss: 2.2533 - val_accuracy: 0.2984
# Epoch 2/10
# 469/469 [==============================] - 151s 322ms/step - loss: 2.2324 - accuracy: 0.2725 - val_loss: 2.1882 - val_accuracy: 0.4777
# Epoch 3/10
# 469/469 [==============================] - 152s 323ms/step - loss: 2.1631 - accuracy: 0.3767 - val_loss: 2.0985 - val_accuracy: 0.5998
# Epoch 4/10
# 469/469 [==============================] - 151s 322ms/step - loss: 2.0638 - accuracy: 0.4744 - val_loss: 1.9663 - val_accuracy: 0.6811
# Epoch 5/10
# 469/469 [==============================] - 152s 323ms/step - loss: 1.9189 - accuracy: 0.5518 - val_loss: 1.7756 - val_accuracy: 0.7465
# Epoch 6/10
# 469/469 [==============================] - 152s 324ms/step - loss: 1.7238 - accuracy: 0.6082 - val_loss: 1.5301 - val_accuracy: 0.7779
# Epoch 7/10
# 469/469 [==============================] - 152s 325ms/step - loss: 1.4982 - accuracy: 0.6502 - val_loss: 1.2675 - val_accuracy: 0.8004
# Epoch 8/10
# 469/469 [==============================] - 152s 324ms/step - loss: 1.2819 - accuracy: 0.6791 - val_loss: 1.0407 - val_accuracy: 0.8154
# Epoch 9/10
# 469/469 [==============================] - 152s 324ms/step - loss: 1.1065 - accuracy: 0.7060 - val_loss: 0.8709 - val_accuracy: 0.8271
# Epoch 10/10
# 469/469 [==============================] - 152s 324ms/step - loss: 0.9836 - accuracy: 0.7248 - val_loss: 0.7520 - val_accuracy: 0.8378
# the model is trained!!
# saved the model as mnist.h5

# %%
pip install win32gui
# Out:
# Collecting win32gui
#   Using cached https://files.pythonhosted.org/packages/b8/75/7bed82934e51903f9d48b26b3996161bb2dce1731607b4bb7fd26003ed3e/win32gui-221.5.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 /usr/local/lib/python3.6/dist-packages/pip/_vendor/pep517/_in_process.py get_requires_for_build_wheel /tmp/tmp3aha48b7 Check the logs for full command output.
